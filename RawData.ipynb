# %% [markdown]
# # Data Exploration

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
# Uploading imputed data to df from CSV WorkingDataFrame
df = pd.read_csv('WorkingDataFrame.csv', index_col=0)
df.head()
# Out:
#       country                                        description  \
# 17  Argentina  Raw black-cherry aromas are direct and simple ...
# 23         US  This wine from the Geneseo district offers aro...
# 36      Chile  White flower, lychee and apple aromas carry th...
# 56         US  This is weighty, creamy and medium to full in ...
# 62         US  The aromas are brooding, with notes of barrel ...
#
#              designation  points  price          province  \
# 17   Winemaker Selection    87.0   13.0  Mendoza Province
# 23   Signature Selection    87.0   22.0        California
# 36                Estate    86.0   15.0  Colchagua Valley
# 56                   NaN    85.0   14.0        California
# 62  Alder Ridge Vineyard    86.0   25.0        Washington
#
#                 region_1         region_2        taster_name  \
# 17               Mendoza              NaN  Michael Schachner
# 23           Paso Robles    Central Coast      Matt Kettmann
# ...
